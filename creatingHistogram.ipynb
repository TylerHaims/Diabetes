# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
/Users/tylerhaims/Documents/GitHub/Diabetes/Diabetes2021

# %%
df_diab = pd.read_csv("/Users/tylerhaims/Documents/GitHub/Diabetes/Diabetes2021/diabetes_binary_health_indicators_BRFSS2021.csv")
df_diab_pos = df_diab[df_diab['Diabetes_binary'] == 1]

df_diab_pos
plt.hist(df_diab_pos['Income'])
plt.xlabel('Income')
plt.ylabel('Frequency')
plt.title('Histogram of diabeetes and income')
# Out:
# Text(0.5, 1.0, 'Histogram of diabeetes and income')

# %%
plt.hist(df_diab_pos['MentHlth'])
plt.xlabel('MentHlth')
plt.ylabel('Frequency')
plt.title('Histogram of diabeetes and MentHlth')
# Out:
# Text(0.5, 1.0, 'Histogram of diabeetes and MentHlth')

# %%
plt.hist(df_diab_pos['Education'])
plt.xlabel('Education')
plt.ylabel('Frequency')
plt.title('Histogram of diabeetes and Education')
# Out:
# Text(0.5, 1.0, 'Histogram of diabeetes and Education')

# %%
plt.hist(df_diab_pos['PhysHlth'])
plt.xlabel('PhysHlth')
plt.ylabel('Frequency')
plt.title('Histogram of diabeetes and PhysHlth')
# Out:
# Text(0.5, 1.0, 'Histogram of diabeetes and PhysHlth')

# %%
plt.hist(df_diab_pos['BMI'])
plt.xlabel('BMI')
plt.ylabel('Frequency')
plt.title('Histogram of diabeetes and BMI')
# Out:
# Text(0.5, 1.0, 'Histogram of diabeetes and BMI')

# %%
plt.hist(df_diab_pos['GenHlth'])
plt.xlabel('GenHlth')
plt.ylabel('Frequency')
plt.title('Histogram of diabeetes and GenHlth')
# Out:
# Text(0.5, 1.0, 'Histogram of diabeetes and GenHlth')

# %%
plt.hist(df_diab_pos['Smoker'])
plt.xlabel('Smoker')
plt.ylabel('Frequency')
plt.title('Histogram of diabeetes and Somker')
# Out:
# Text(0.5, 1.0, 'Histogram of diabeetes and Somker')

# %%
plt.hist(df_diab_pos['Stroke'])
plt.xlabel('Stroke')
plt.ylabel('Frequency')
plt.title('Histogram of diabeetes and Stroke')
# Out:
# Text(0.5, 1.0, 'Histogram of diabeetes and Stroke')

# %%
plt.hist(df_diab_pos['HvyAlcoholConsump'])
plt.xlabel('HvyAlcoholConsump')
plt.ylabel('Frequency')
plt.title('Histogram of diabeetes and HvyAlcoholConsump')
# Out:
# Text(0.5, 1.0, 'Histogram of diabeetes and HvyAlcoholConsump')
